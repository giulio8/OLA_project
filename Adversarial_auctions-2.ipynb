# %%
import numpy as np
import matplotlib.pyplot as plt
#!pip install scipy
from scipy import stats
from scipy import optimize
from math import sin

# %%
class Auction:
    def __init__(self, *args, **kwargs):
        pass

    def get_winners(self, bids):
        pass

    def get_payments_per_click(self, winners, values, bids):
        pass

    def round(self, bids):
        winners, values = self.get_winners(bids) # allocation mechanism!
        payments_per_click = self.get_payments_per_click(winners, values, bids)
        return winners, payments_per_click

# %%
class FirstPriceAuction(Auction):
    def __init__(self, ctrs):
        self.ctrs = ctrs
        self.n_adv = len(self.ctrs)

    def get_winners(self, bids):
        adv_values = self.ctrs*bids
        adv_ranking = np.argsort(adv_values)
        winner = adv_ranking[-1]
        return winner, adv_values

    def get_payments_per_click(self, winners, values, bids):
        payment = bids[winners]
        return payment.round(2)

# %%
##### NEW CLASS TO HAVE MULTIPLE SLOTS
class FirstPriceAuction(Auction):
    def __init__(self, ctrs):
        self.ctrs = ctrs
        self.n_adv = len(self.ctrs)

    def get_winners(self, bids):
        adv_values = self.ctrs*bids
        adv_ranking = np.argsort(adv_values)
        winner = [adv_ranking[-1], adv_ranking[-2], adv_ranking[-3]] ## FOR NOW WE ARE USING 3 WINNING SLOTS
        return winner, adv_values

    def get_payments_per_click(self, winners, values, bids):
      payment = []
      for i in len(winners):
          payment[i] = bids[winners[i]] ## WE HAD CHANGE ALSO THIS BECAUSE THERE WILL BE A PAYMENT FOR EACH WINNER
          payment[i].round(2)
      return payment

# %% [markdown]
# Let's configure the parameters to have the same values of the other parts of the project

# %%
import numpy as np

# Configuration parameters
ITERATIONS = 1000
AUCTIONS = 100
N_USERS = 100
N_ADVERTISERS = 10    # number of companies that compete for slot auctions, including myself
NUMBER_OF_ARMS = 100    # needed for the UCB algorithm
PRICES = np.linspace(0, 1, NUMBER_OF_ARMS)    # actual arms of the ucb algorithm
BUGDET = 40 # I know it's mispelled but i found it like this in the other file so i kept it like this
NUMBER_OF_SLOTS = 10

lambda_fun_param = lambda s: 1/(s+(0.3))       # probability of the ad being seen given the position s ->  0.5 for first position, 0.33 for second, 0.25 for third, etc...
LAMBDAS = np.array([lambda_fun_param(i) for i in range(1, NUMBER_OF_SLOTS+1)])    # array of lambda values (for each slot)

# %% [markdown]
# Pattern definition

# %%
### Adversarial Bidders
#### interest !!
my_valuation = [0.8, 0.6, 0.4] #used in c ## NOW THERE ARE 3
rho = BUGDET/N_USERS

# non-trivial scenario: competitors sample bids from a uniform with range varying over time
pattern = lambda t: 1-np.abs(np.sin(50*t/N_USERS))
other_bids = np.array([np.random.uniform(0, pattern(t), size = N_ADVERTISERS) for t in range(N_USERS)]).T
# I assume that competitors may have a larger budget than mine, but they may
# not deplete it.

m_t = other_bids.max(axis=0)

plt.plot(m_t)
plt.title('Expected maximum bid')
plt.xlabel('$t$')
plt.ylabel('$m_t$')
plt.show()

# %% [markdown]
# clairvoyant

# %%
available_bids = np.linspace(0,1,11)
win_probabilities = np.array([sum(b > m_t)/N_USERS for b in available_bids])
## Linear Program
#linprog is a wayto optimize the function and the bid
c = -(my_valuation-available_bids)*win_probabilities
A_ub = [available_bids*win_probabilities]
b_ub = [rho]
A_eq = [np.ones(len(available_bids))]
b_eq = [1]
res = optimize.linprog(c, A_ub=A_ub, b_ub=b_ub, A_eq=A_eq, b_eq=b_eq, bounds=(0,1))
gamma = res.x
expected_clairvoyant_utilities = [-res.fun for u in range(N_USERS)]
expected_clairvoyant_bids = [sum(available_bids*gamma*win_probabilities) for u in range(N_USERS)]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-6a88e0669068> in <cell line: 5>()
#       3 ## Linear Program
#       4 #linprog is a wayto optimize the function and the bid
# ----> 5 c = -(my_valuation-available_bids)*win_probabilities
#       6 A_ub = [available_bids*win_probabilities]
#       7 b_ub = [rho]
#
# ValueError: operands could not be broadcast together with shapes (3,) (11,)

# %%
### THIS IS THE NEW BLOCK FOR THE CLAIRVOYANT INCLUDING MORE SLOTS
available_bids = np.linspace(0,1,11)
win_probabilities = np.array([sum(b > m_t)/N_USERS for b in available_bids])
## Linear Program
#linprog is a wayto optimize the function and the bid
k = np.array([])
i = 0

## WE CONSIDERED C AS THE MEAN BECAUSE MY BID WILL BE ACTIVE FOR ALL THE 3 SLOTS, SO I NEED A UNIQUE VALUATION TO CHOOSE MY BID
while i < len(my_valuation):
  k = np.append(k,-(my_valuation[i]-available_bids)*win_probabilities)
  i+=1

k_reshaped = k.reshape(3, 11)
c = np.mean(k_reshaped, axis = 0) ## HERE WE COMPUTE THE MEAN
A_ub = [available_bids*win_probabilities]
b_ub = [rho]
A_eq = [np.ones(len(available_bids))]
b_eq = [1]
res = optimize.linprog(c, A_ub=A_ub, b_ub=b_ub, A_eq=A_eq, b_eq=b_eq, bounds=(0,1))
gamma = res.x
expected_clairvoyant_utilities = [-res.fun for u in range(N_USERS)]
expected_clairvoyant_bids = [sum(available_bids*gamma*win_probabilities) for u in range(N_USERS)]

# %% [markdown]
# ### Generalized Multiplicative Pacing for Non-Truthful Auctions

# %% [markdown]
# #### Here, we will assume a **full-feedback** setting. In auctions, full-feedback is equivalent of knowing the maximum bid $m_t$ that won the auction (of course, **after** the auction). Moreover, bids will be **discretized** into a finite set of actions.
# Full feedback = You know th bid of each competitor

# %% [markdown]
# #### We will leverage a full-feedback, adversarial learner such as Hedge (see Lab 2).

# %%
class HedgeAgent:
    def __init__(self, narms, learning_rate): #ho tolto il numero di slot da questa classe per tenere solo narms
        self.narms = narms   #number of possible bids
        self.learning_rate = learning_rate #supposing it's the rate at which the algorithm progress
        self.weights = np.ones(narms) #weight == proportionnal to the probabilty
        self.x_t = np.ones(narms)/narms #probability of a bid to be played
        self.a_t = None # bid choice done during the round
        self.t = 0

    def pull_arm(self): #choose which arm to play
        self.x_t = self.weights/sum(self.weights)
        self.a_t = np.random.choice(np.arange(self.narms), p=self.x_t)
        return self.a_t

    def update(self, l_t): #update the weights
        self.weights *= np.exp(-self.learning_rate*l_t)
        self.t += 1

# %%
class FFMultiplicativePacingAgent:
    def __init__(self, bids_set, valuation, budget, T, eta):
        self.bids_set = bids_set #available choices
        self.narms = len(bids_set) #nuber of bid choices
        self.hedge = HedgeAgent(self.narms, np.sqrt(np.log(self.narms)/T)) #qui ci va narms o nslots?? ma come learning rate non ci andrebbe eta??
        self.valuation = valuation #what you earn, ctr*profit_per_click
        self.budget = budget
        self.eta = eta #learning rate
        self.T = T  #number of rounds
        self.rho = self.budget/self.T #bid limit
        self.lmbd = 1 #pacing multiplier, when we spend more than rho it increses otherwise we decrease it
        self.t = 0

    def bid(self):
        if self.budget < 1:
            return 0
        return self.bids_set[self.hedge.pull_arm()]

    def update(self, f_t, c_t, m_t):
        # update hedge
        f_t_full = np.array([(np.mean(self.valuation)-b)*int(b >= m_t) for b in self.bids_set]) ## WE TOOK THE MEAN OF MY VALUATION
        c_t_full = np.array([b*int(b >= m_t) for b in self.bids_set])
        L = f_t_full - self.lmbd*(c_t_full-self.rho)
        range_L = 2+(1-self.rho)/self.rho
        self.hedge.update((2-L)/range_L) # hedge needs losses in [0,1]
        # update lagrangian multiplier
        self.lmbd = np.clip(self.lmbd-self.eta*(self.rho-c_t),
                            a_min=0, a_max=1/self.rho)
        # update budget
        self.budget -= c_t

# %% [markdown]
# ## Trial

# %% [markdown]
# First iteration

# %%
eta = 1/np.sqrt(N_USERS)  # Learning rate from theory

# Initializing the agent and auction
agent = FFMultiplicativePacingAgent(bids_set=available_bids,
                                    valuation=my_valuation,
                                    budget=BUGDET,
                                    T=N_USERS,
                                    eta=eta)

auction = FirstPriceAuction(np.ones(N_ADVERTISERS + 1))  # Auction setup

# Arrays to store results
utilities = np.array([])  # Utility gained in each auction
my_bids = np.array([])  # Bids placed by the agent
my_payments = np.array([])  # Payments made by the agent
total_wins = 0  # Counter for total wins

# Running the auction process
np.random.seed(1)  # Seed for reproducibility

for u in range(N_USERS):
    # Agent places a bid
    my_bid = agent.bid()

    # Gather all bids for this auction
    bids = np.append(my_bid, other_bids[:, u].ravel())
    m_t_new = np.max(bids)

    # Determine winners and payments
    winners, payments_per_click = auction.round(bids=bids)

    # Check if the agent won
    my_win = int(winners == 0)  # Agent wins if winners is 0

    # Calculate the utility and payment for the agent
    f_t = (my_valuation - m_t_new) * my_win  # Utility when the agent wins
    c_t = m_t_new * my_win  # Payment if the agent wins

    # Update the agent's learning based on the auction outcome
    agent.update(f_t, c_t, m_t_new)

    # Store the results
    utilities = np.append(utilities, f_t)  # Append utility
    my_bids = np.append(my_bids, my_bid)  # Append bid
    my_payments = np.append(my_payments, c_t)  # Append payment
    total_wins += my_win  # Increment total wins

    cumulative_payments = np.cumsum(my_payments)

    # Nicely formatted output to track progress
    print(f"\nIteration {u}:")  # New line for each iteration
    print(f"  My bid            : {my_bid:.2f}")
    print(f"  All bids          : {bids}")
    print(f"  Winners           : {winners}")
    print(f"  My win            : {my_win}")
    print(f"  m_t[{u}]          : {m_t_new:.2f}")
    print(f"  c_t               : {c_t:.2f}")
    print(f"  Total wins so far : {total_wins}")
    print(f"  Current payment : {my_payments[u]}")
    print(f"  Total paid so far : {cumulative_payments[u]}")

# Display total number of wins at the end
print(f"Total number of wins: {total_wins}")

### PROBLEM: in the next blocks we see from the graph that we never pay anything, that's because tha variable my_payments doesn't update and stays null
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-239439774ffb> in <cell line: 21>()
#      28
#      29     # Determine winners and payments
# ---> 30     winners, payments_per_click = auction.round(bids=bids)
#      31
#      32     # Check if the agent won
#
# <ipython-input-2-c403f28feadd> in round(self, bids)
#      11     def round(self, bids):
#      12         winners, values = self.get_winners(bids) # allocation mechanism!
# ---> 13         payments_per_click = self.get_payments_per_click(winners, values, bids)
#      14         return winners, payments_per_click
#
# <ipython-input-3-68efac75f9b8> in get_payments_per_click(self, winners, values, bids)
#      12     def get_payments_per_click(self, winners, values, bids):
#      13       payment = []
# ---> 14       for i in len(winners):
#      15           payment[i] = bids[winners[i]]
#      16           payment[i].round(2)
#
# TypeError: 'int' object is not iterable

# %%
### THIS IS THE NEW BLOCK OF THE FIRST TRIAL CONSIDERING MULTIPLE SLOTS
eta = 1/np.sqrt(N_USERS)  # Learning rate from theory

# Initializing the agent and auction
agent = FFMultiplicativePacingAgent(bids_set=available_bids,
                                    valuation=my_valuation,
                                    budget=BUGDET,
                                    T=N_USERS,
                                    eta=eta)

auction = FirstPriceAuction(np.ones(N_ADVERTISERS + 1))  # Auction setup

# Arrays to store results
utilities = np.array([])  # Utility gained in each auction
my_bids = np.array([])  # Bids placed by the agent
my_payments = np.array([])  # Payments made by the agent
total_wins = 0  # Counter for total wins

# Running the auction process
np.random.seed(1)  # Seed for reproducibility

for u in range(N_USERS):
    my_win = 0
    rank = 0
    # Agent places a bid
    my_bid = agent.bid()

    # Gather all bids for this auction
    bids = np.append(my_bid, other_bids[:, u].ravel())
    m_t_new = np.max(bids)

    # Determine winners and payments
    winners, payments_per_click = auction.get_winners(bids=bids)
    x = len(winners)

    # Check if the agent won
    #WE ADDED THIS FOR CICLE TO CHECK IF I WON AT LEAST ONE SLOT
    for i in range(x):
      if winners[i]==0:
        my_win = 1
        rank = i # THIS IS TO CHEK LATER THE UTILITY CONSIDERING THE VALUATION OF THE SLOT I WON

    # Calculate the utility and payment for the agent
    f_t = (my_valuation[rank] - m_t_new) * my_win  # Utility when the agent wins #WE ARE CONSIDERING RANK FOR THE RIGHT VALUATION
    c_t = m_t_new * my_win  # Payment if the agent wins

    # Update the agent's learning based on the auction outcome
    agent.update(f_t, c_t, m_t_new)

    # Store the results
    utilities = np.append(utilities, f_t)  # Append utility
    my_bids = np.append(my_bids, my_bid)  # Append bid
    my_payments = np.append(my_payments, c_t)  # Append payment
    total_wins += my_win  # Increment total wins

    cumulative_payments = np.cumsum(my_payments)

    # Nicely formatted output to track progress
    print(f"\nIteration {u}:")  # New line for each iteration
    print(f"  My bid            : {my_bid:.2f}")
    print(f"  All bids          : {bids}")
    print(f"  Winners           : {winners}")
    print(f"  My win            : {my_win}")
    print(f"  m_t[{u}]          : {m_t_new:.2f}")
    print(f"  c_t               : {c_t:.2f}")
    print(f"  Total wins so far : {total_wins}")
    print(f"  Current payment : {my_payments[u]}")
    print(f"  Total paid so far : {cumulative_payments[u]}")

# Display total number of wins at the end
print(f"Total number of wins: {total_wins}")
# Out:
# Iteration 0:
#   My bid            : 0.40
#   All bids          : [0.4        0.30280931 0.62531137 0.53917992 0.81251216 0.26815162
#  0.02844154 0.79302023 0.56394302 0.64552991 0.59732716]
#   Winners           : [4, 7, 9]
#   My win            : 0
#   m_t[0]          : 0.81
#   c_t               : 0.00
#   Total wins so far : 0
#   Current payment : 0.0
#   Total paid so far : 0.0
#
# Iteration 1:
#   My bid            : 0.70
#   All bids          : [0.7        0.33978091 0.11228937 0.1161675  0.51647799 0.16754452
#  0.01299794 0.51404493 0.07338996 0.0100236  0.24573337]
#   Winners           : [0, 4, 7]
#   My win            : 1
#   m_t[1]          : 0.70
#   c_t               : 0.70
#   Total wins so far : 1
#   Current payment : 0.7000000000000001
#   Total paid so far : 0.7000000000000001
#
# Iteration 2:
#   My bid            : 0.00
#   All bids          : [0.         0.1079549  0.09120318 0.12656005 0.14460171 0.14066043
#  0.1385712  0.11794585 0.14246715 0.0106381  0.02648438]
#   Winners           : [4, 8, 5]
#   My win            : 0
#   m_t[2]          : 0.14
#   c_t               : 0.00
#   Total wins so far : 1
#   Current payment : 0.0
#   Total paid so far : 0.7000000000000001
#
# Iteration 3:
#   My bid            : 0.30
#   All bids          : [0.3        0.00163493 0.00122226 0.00238946 0.00139422 0.0024188
#  0.00095213 0.00187173 0.00138591 0.00101899 0.00128926]
#   Winners           : [0, 5, 3]
#   My win            : 1
#   m_t[3]          : 0.30
#   c_t               : 0.30
#   Total wins so far : 2
#   Current payment : 0.30000000000000004
#   Total paid so far : 1.0
#
# Iteration 4:
#   My bid            : 0.10
#   All bids          : [0.1        0.08222035 0.02882025 0.05340308 0.06779574 0.04263771
#  0.00187224 0.07392811 0.05603933 0.02327008 0.05948137]
#   Winners           : [0, 1, 7]
#   My win            : 1
#   m_t[4]          : 0.10
#   c_t               : 0.10
#   Total wins so far : 3
#   Current payment : 0.1
#   Total paid so far : 1.1
#
# Iteration 5:
#   My bid            : 0.00
#   All bids          : [0.         0.30547477 0.34138874 0.35024912 0.29519282 0.38690018
#  0.14651997 0.31143098 0.12119476 0.0747884  0.26742505]
#   Winners           : [5, 3, 2]
#   My win            : 0
#   m_t[5]          : 0.39
#   c_t               : 0.00
#   Total wins so far : 3
#   Current payment : 0.0
#   Total paid so far : 1.1
#
# Iteration 6:
#   My bid            : 0.10
#   All bids          : [0.1        0.07896187 0.7919442  0.14380823 0.45972901 0.12341939
#  0.03957087 0.24094298 0.6188322  0.4433984  0.39213756]
#   Winners           : [2, 8, 4]
#   My win            : 0
#   m_t[6]          : 0.79
#   c_t               : 0.00
#   Total wins so far : 3
#   Current payment : 0.0
#   Total paid so far : 1.1
#
# Iteration 7:
#   My bid            : 0.30
#   All bids          : [0.3        0.27678256 0.4206079  0.13481665 0.61509942 0.26462473
#  0.26810138 0.59936326 0.22989461 0.54492336 0.53224589]
#   Winners           : [4, 7, 9]
#   My win            : 0
#   m_t[7]          : 0.62
#   c_t               : 0.00
#   Total wins so far : 3
#   Current payment : 0.0
#   Total paid so far : 1.1
#
# Iteration 8:
#   My bid            : 0.30
#   All bids          : [0.3        0.22635491 0.15076935 0.07307027 0.18936661 0.23027058
#  0.02816326 0.07277214 0.02499702 0.12227814 0.08373043]
#   Winners           : [0, 5, 1]
#   My win            : 1
#   m_t[8]          : 0.30
#   c_t               : 0.30
#   Total wins so far : 4
#   Current payment : 0.30000000000000004
#   Total paid so far : 1.4000000000000001
#
# Iteration 9:
#   My bid            : 0.50
#   All bids          : [0.5        0.02172533 0.00912793 0.00285248 0.01260585 0.00370837
#  0.0070951  0.00607832 0.01252905 0.02222229 0.0193859 ]
#   Winners           : [0, 9, 1]
#   My win            : 1
#   m_t[9]          : 0.50
#   c_t               : 0.50
#   Total wins so far : 5
#   Current payment : 0.5
#   Total paid so far : 1.9000000000000001
#
# Iteration 10:
#   My bid            : 0.30
#   All bids          : [0.3        0.00096453 0.03757149 0.0392829  0.03304459 0.02445024
#  0.03219083 0.01077826 0.00897452 0.01637526 0.037034  ]
#   Winners           : [0, 3, 2]
#   My win            : 1
#   m_t[10]          : 0.30
#   c_t               : 0.30
#   Total wins so far : 6
#   Current payment : 0.30000000000000004
#   Total paid so far : 2.2
#
# Iteration 11:
#   My bid            : 0.60
#   All bids          : [0.6        0.05558235 0.16325205 0.04204339 0.26523861 0.19022415
#  0.19287501 0.18007907 0.06840268 0.25397423 0.09836988]
#   Winners           : [0, 4, 9]
#   My win            : 1
#   m_t[11]          : 0.60
#   c_t               : 0.60
#   Total wins so far : 7
#   Current payment : 0.6000000000000001
#   Total paid so far : 2.8000000000000003
#
# Iteration 12:
#   My bid            : 0.10
#   All bids          : [0.1        0.02519375 0.54670984 0.51168488 0.33706809 0.01272917
#  0.14357121 0.1767238  0.18435618 0.31240693 0.03709717]
#   Winners           : [2, 3, 4]
#   My win            : 0
#   m_t[12]          : 0.55
#   c_t               : 0.00
#   Total wins so far : 7
#   Current payment : 0.0
#   Total paid so far : 2.8000000000000003
#
# Iteration 13:
#   My bid            : 0.80
#   All bids          : [0.8        0.69777563 0.58583385 0.70904387 0.47770808 0.17571942
#  0.66868451 0.21034783 0.23647567 0.00979029 0.46117114]
#   Winners           : [0, 3, 1]
#   My win            : 1
#   m_t[13]          : 0.80
#   c_t               : 0.80
#   Total wins so far : 8
#   Current payment : 0.8
#   Total paid so far : 3.6000000000000005
#
# Iteration 14:
#   My bid            : 0.00
#   All bids          : [0.         0.117844   0.30873238 0.20578489 0.17264158 0.10896618
#  0.01653349 0.13230885 0.19719111 0.32630231 0.11373189]
#   Winners           : [9, 2, 3]
#   My win            : 0
#   m_t[14]          : 0.33
#   c_t               : 0.00
#   Total wins so far : 8
#   Current payment : 0.0
#   Total paid so far : 3.6000000000000005
#
# Iteration 15:
#   My bid            : 0.60
#   All bids          : [0.6        0.05380853 0.00815439 0.01312349 0.02042253 0.00525648
#  0.04674237 0.01002791 0.00213567 0.01919376 0.01642292]
#   Winners           : [0, 1, 6]
#   My win            : 1
#   m_t[15]          : 0.60
#   c_t               : 0.60
#   Total wins so far : 9
#   Current payment : 0.6000000000000001
#   Total paid so far : 4.200000000000001
#
# Iteration 16:
#   My bid            : 0.30
#   All bids          : [0.3        0.0028361  0.0028542  0.0056133  0.0056797  0.00685636
#  0.01037705 0.00250922 0.00882538 0.00311338 0.00333712]
#   Winners           : [0, 6, 8]
#   My win            : 1
#   m_t[16]          : 0.30
#   c_t               : 0.30
#   Total wins so far : 10
#   Current payment : 0.30000000000000004
#   Total paid so far : 4.500000000000001
#
# Iteration 17:
#   My bid            : 0.40
#   All bids          : [0.4        0.08340763 0.02527141 0.07880121 0.07838384 0.17886852
#  0.04178133 0.10128233 0.19704105 0.02614107 0.16891831]
#   Winners           : [0, 8, 5]
#   My win            : 1
#   m_t[17]          : 0.40
#   c_t               : 0.40
#   Total wins so far : 11
#   Current payment : 0.4
#   Total paid so far : 4.900000000000001
#
# Iteration 18:
#   My bid            : 0.10
#   All bids          : [0.1        0.10929057 0.33517705 0.5173354  0.28151437 0.25219918
#  0.58121825 0.41178041 0.08574714 0.47910968 0.05298531]
#   Winners           : [6, 3, 9]
#   My win            : 0
#   m_t[18]          : 0.58
#   c_t               : 0.00
#   Total wins so far : 11
#   Current payment : 0.0
#   Total paid so far : 4.900000000000001
#
# Iteration 19:
#   My bid            : 0.10
#   All bids          : [0.1        0.59932211 0.08023672 0.86120364 0.69898017 0.35581554
#  0.39292256 0.10714312 0.07071602 0.78623758 0.03651942]
#   Winners           : [3, 9, 4]
#   My win            : 0
#   m_t[19]          : 0.86
#   c_t               : 0.00
#   Total wins so far : 11
#   Current payment : 0.0
#   Total paid so far : 4.900000000000001
#
# Iteration 20:
#   My bid            : 0.70
#   All bids          : [0.7        0.14406963 0.31700524 0.21855531 0.43399738 0.21468765
#  0.09546464 0.26017408 0.22463643 0.08393772 0.08800171]
#   Winners           : [0, 4, 2]
#   My win            : 1
#   m_t[20]          : 0.70
#   c_t               : 0.70
#   Total wins so far : 12
#   Current payment : 0.7000000000000001
#   Total paid so far : 5.600000000000001
#
# Iteration 21:
#   My bid            : 1.00
#   All bids          : [1.         0.06137415 0.04510297 0.05162764 0.10350363 0.0031268
#  0.04762226 0.00537291 0.07906634 0.07953298 0.06816496]
#   Winners           : [0, 4, 9]
#   My win            : 1
#   m_t[21]          : 1.00
#   c_t               : 1.00
#   Total wins so far : 13
#   Current payment : 1.0
#   Total paid so far : 6.600000000000001
#
# Iteration 22:
#   My bid            : 0.20
#   All bids          : [2.00000000e-01 9.59145557e-06 4.83252580e-06 7.19007562e-06
#  4.60084119e-06 9.04260977e-06 3.88771295e-07 7.48179281e-06
#  6.92048118e-06 1.86698493e-06 7.43476710e-08]
#   Winners           : [0, 1, 5]
#   My win            : 1
#   m_t[22]          : 0.20
#   c_t               : 0.20
#   Total wins so far : 14
#   Current payment : 0.2
#   Total paid so far : 6.800000000000002
#
# Iteration 23:
#   My bid            : 0.50
#   All bids          : [0.5        0.06634559 0.04902119 0.11005066 0.02365551 0.08302582
#  0.08507441 0.08075414 0.0685743  0.02919246 0.02694927]
#   Winners           : [0, 3, 6]
#   My win            : 1
#   m_t[23]          : 0.50
#   c_t               : 0.50
#   Total wins so far : 15
#   Current payment : 0.5
#   Total paid so far : 7.300000000000002
#
# Iteration 24:
#   My bid            : 0.80
#   All bids          : [0.8        0.28917623 0.11934224 0.07583658 0.16598091 0.09566775
#  0.32728881 0.18268122 0.38862006 0.0146598  0.44707172]
#   Winners           : [0, 10, 8]
#   My win            : 1
#   m_t[24]          : 0.80
#   c_t               : 0.80
#   Total wins so far : 16
#   Current payment : 0.8
#   Total paid so far : 8.100000000000001
#
# Iteration 25:
#   My bid            : 0.80
#   All bids          : [0.8        0.02599511 0.41674453 0.34167085 0.01942116 0.69702764
#  0.15071237 0.67601571 0.38115431 0.73132805 0.09135031]
#   Winners           : [0, 9, 5]
#   My win            : 1
#   m_t[25]          : 0.80
#   c_t               : 0.80
#   Total wins so far : 17
#   Current payment : 0.8
#   Total paid so far : 8.900000000000002
#
# Iteration 26:
#   My bid            : 0.00
#   All bids          : [0.         0.00436318 0.09030553 0.05072153 0.45038472 0.05035177
#  0.07653739 0.11292752 0.52846163 0.3186717  0.24828743]
#   Winners           : [8, 4, 9]
#   My win            : 0
#   m_t[26]          : 0.53
#   c_t               : 0.00
#   Total wins so far : 17
#   Current payment : 0.0
#   Total paid so far : 8.900000000000002
#
# Iteration 27:
#   My bid            : 0.00
#   All bids          : [0.         0.04334692 0.02270003 0.05329573 0.0129582  0.04631058
#  0.01640292 0.14574406 0.05457046 0.14427149 0.1527018 ]
#   Winners           : [10, 7, 9]
#   My win            : 0
#   m_t[27]          : 0.15
#   c_t               : 0.00
#   Total wins so far : 17
#   Current payment : 0.0
#   Total paid so far : 8.900000000000002
#
# Iteration 28:
#   My bid            : 0.10
#   All bids          : [1.00000000e-01 8.64664996e-05 2.49315062e-03 4.57014321e-03
#  4.75756206e-03 6.21693485e-03 1.84336788e-04 9.57392515e-04
#  1.64755887e-04 7.61756694e-03 2.19097472e-03]
#   Winners           : [0, 9, 5]
#   My win            : 1
#   m_t[28]          : 0.10
#   c_t               : 0.10
#   Total wins so far : 18
#   Current payment : 0.1
#   Total paid so far : 9.000000000000002
#
# Iteration 29:
#   My bid            : 0.70
#   All bids          : [0.7        0.02511277 0.0609518  0.01813605 0.02474093 0.04280898
#  0.01275856 0.02826121 0.06311263 0.04473859 0.00864455]
#   Winners           : [0, 8, 2]
#   My win            : 1
#   m_t[29]          : 0.70
#   c_t               : 0.70
#   Total wins so far : 19
#   Current payment : 0.7000000000000001
#   Total paid so far : 9.700000000000001
#
# Iteration 30:
#   My bid            : 0.00
#   All bids          : [0.         0.27320963 0.02475821 0.17768007 0.34434281 0.29663532
#  0.26455477 0.23804954 0.10074857 0.27330652 0.24139393]
#   Winners           : [4, 5, 9]
#   My win            : 0
#   m_t[30]          : 0.34
#   c_t               : 0.00
#   Total wins so far : 19
#   Current payment : 0.0
#   Total paid so far : 9.700000000000001
#
# Iteration 31:
#   My bid            : 0.30
#   All bids          : [0.3        0.00576068 0.02654149 0.53415951 0.48886898 0.17483343
#  0.37977862 0.33462751 0.52845389 0.73837196 0.48057271]
#   Winners           : [9, 3, 8]
#   My win            : 0
#   m_t[31]          : 0.74
#   c_t               : 0.00
#   Total wins so far : 19
#   Current payment : 0.0
#   Total paid so far : 9.700000000000001
#
# Iteration 32:
#   My bid            : 0.90
#   All bids          : [0.9        0.15321226 0.62142579 0.21096097 0.44818961 0.45861084
#  0.47211373 0.07475086 0.13772871 0.38018741 0.46569345]
#   Winners           : [0, 2, 6]
#   My win            : 1
#   m_t[32]          : 0.90
#   c_t               : 0.90
#   Total wins so far : 20
#   Current payment : 0.9
#   Total paid so far : 10.600000000000001
#
# Iteration 33:
#   My bid            : 0.40
#   All bids          : [0.4        0.18214985 0.09681665 0.09984039 0.17287931 0.02336705
#  0.1779499  0.21793143 0.16544702 0.01132774 0.21145109]
#   Winners           : [0, 7, 10]
#   My win            : 1
#   m_t[33]          : 0.40
#   c_t               : 0.40
#   Total wins so far : 21
#   Current payment : 0.4
#   Total paid so far : 11.000000000000002
#
# Iteration 34:
#   My bid            : 0.50
#   All bids          : [5.00000000e-01 7.57961566e-05 3.05305269e-02 6.88834613e-03
#  1.08447001e-02 1.97815092e-02 9.50839873e-03 4.12185452e-03
#  1.93587454e-02 3.74574338e-02 1.49350365e-03]
#   Winners           : [0, 9, 2]
#   My win            : 1
#   m_t[34]          : 0.50
#   c_t               : 0.50
#   Total wins so far : 22
#   Current payment : 0.5
#   Total paid so far : 11.500000000000002
#
# Iteration 35:
#   My bid            : 0.20
#   All bids          : [2.00000000e-01 1.49354751e-02 2.41262957e-02 1.17042035e-02
#  1.08715286e-02 2.22689183e-03 1.72063656e-04 4.48869151e-03
#  4.06365592e-03 2.04812919e-02 2.39713183e-02]
#   Winners           : [0, 2, 10]
#   My win            : 1
#   m_t[35]          : 0.20
#   c_t               : 0.20
#   Total wins so far : 23
#   Current payment : 0.2
#   Total paid so far : 11.700000000000001
#
# Iteration 36:
#   My bid            : 0.50
#   All bids          : [5.00000000e-01 1.46324112e-01 1.15621502e-01 1.86903374e-01
#  1.00775431e-01 1.80031532e-01 6.63487534e-02 1.55265222e-04
#  1.44870997e-01 8.10142507e-02 1.92439996e-02]
#   Winners           : [0, 3, 5]
#   My win            : 1
#   m_t[36]          : 0.50
#   c_t               : 0.50
#   Total wins so far : 24
#   Current payment : 0.5
#   Total paid so far : 12.200000000000001
#
# Iteration 37:
#   My bid            : 0.60
#   All bids          : [0.6        0.36073991 0.64145629 0.65380445 0.5562643  0.62210132
#  0.11335267 0.43219825 0.38784318 0.28239532 0.21561421]
#   Winners           : [3, 2, 5]
#   My win            : 0
#   m_t[37]          : 0.65
#   c_t               : 0.00
#   Total wins so far : 24
#   Current payment : 0.0
#   Total paid so far : 12.200000000000001
#
# Iteration 38:
#   My bid            : 0.00
#   All bids          : [0.         0.71058404 0.54893251 0.25040235 0.37022822 0.56633925
#  0.53917303 0.25857064 0.53128686 0.41155593 0.19121007]
#   Winners           : [1, 5, 2]
#   My win            : 0
#   m_t[38]          : 0.71
#   c_t               : 0.00
#   Total wins so far : 24
#   Current payment : 0.0
#   Total paid so far : 12.200000000000001
#
# Iteration 39:
#   My bid            : 0.50
#   All bids          : [0.5        0.39352858 0.38769481 0.03288208 0.09708381 0.1800687
#  0.25605607 0.19765332 0.06768051 0.18736243 0.25365674]
#   Winners           : [0, 1, 2]
#   My win            : 1
#   m_t[39]          : 0.50
#   c_t               : 0.50
#   Total wins so far : 25
#   Current payment : 0.5
#   Total paid so far : 12.700000000000001
#
# Iteration 40:
#   My bid            : 1.00
#   All bids          : [1.         0.05991741 0.0593515  0.06999726 0.07048005 0.0230837
#  0.0809834  0.00991133 0.01328232 0.06757993 0.06732465]
#   Winners           : [0, 6, 4]
#   My win            : 1
#   m_t[40]          : 1.00
#   c_t               : 1.00
#   Total wins so far : 26
#   Current payment : 1.0
#   Total paid so far : 13.700000000000001
#
# Iteration 41:
#   My bid            : 0.50
#   All bids          : [5.00000000e-01 1.03631058e-03 3.07662508e-03 2.36058883e-03
#  1.22112863e-03 1.07367001e-03 2.89247824e-03 2.44658416e-03
#  1.66900679e-04 2.69806947e-03 2.27052013e-05]
#   Winners           : [0, 2, 6]
#   My win            : 1
#   m_t[41]          : 0.50
#   c_t               : 0.50
#   Total wins so far : 27
#   Current payment : 0.5
#   Total paid so far : 14.200000000000001
#
# Iteration 42:
#   My bid            : 0.20
#   All bids          : [0.2        0.07789043 0.04217624 0.14046048 0.15650419 0.02441019
#  0.07874641 0.15098673 0.00297508 0.04297713 0.13297708]
#   Winners           : [0, 4, 7]
#   My win            : 1
#   m_t[42]          : 0.20
#   c_t               : 0.20
#   Total wins so far : 28
#   Current payment : 0.2
#   Total paid so far : 14.4
#
# Iteration 43:
#   My bid            : 0.50
#   All bids          : [0.5        0.03982424 0.00315174 0.12804453 0.24413635 0.17661932
#  0.24300044 0.05995394 0.29678217 0.3262297  0.24479056]
#   Winners           : [0, 9, 8]
#   My win            : 1
#   m_t[43]          : 0.50
#   c_t               : 0.50
#   Total wins so far : 29
#   Current payment : 0.5
#   Total paid so far : 14.9
#
# Iteration 44:
#   My bid            : 0.00
#   All bids          : [0.         0.95432358 0.62703371 0.39596769 0.30089404 0.1407676
#  0.72417913 0.46033857 0.3300023  0.10921947 0.17489217]
#   Winners           : [1, 6, 2]
#   My win            : 0
#   m_t[44]          : 0.95
#   c_t               : 0.00
#   Total wins so far : 29
#   Current payment : 0.0
#   Total paid so far : 14.9
#
# Iteration 45:
#   My bid            : 0.30
#   All bids          : [0.3        0.43322494 0.15770711 0.22542058 0.06371058 0.20962935
#  0.30165221 0.30452732 0.15472587 0.40618599 0.32253672]
#   Winners           : [1, 9, 10]
#   My win            : 0
#   m_t[45]          : 0.43
#   c_t               : 0.00
#   Total wins so far : 29
#   Current payment : 0.0
#   Total paid so far : 14.9
#
# Iteration 46:
#   My bid            : 0.70
#   All bids          : [0.7        0.10026611 0.0866645  0.06198398 0.14172654 0.13946524
#  0.07638623 0.02108057 0.02161225 0.12915264 0.15118077]
#   Winners           : [0, 10, 4]
#   My win            : 1
#   m_t[46]          : 0.70
#   c_t               : 0.70
#   Total wins so far : 30
#   Current payment : 0.7000000000000001
#   Total paid so far : 15.6
#
# Iteration 47:
#   My bid            : 0.20
#   All bids          : [2.00000000e-01 6.58015621e-04 8.96993898e-04 1.60190517e-03
#  1.88938444e-03 9.01908041e-05 5.44326109e-04 1.82261915e-03
#  1.17892195e-03 1.43913965e-03 1.42068318e-03]
#   Winners           : [0, 4, 7]
#   My win            : 1
#   m_t[47]          : 0.20
#   c_t               : 0.20
#   Total wins so far : 31
#   Current payment : 0.2
#   Total paid so far : 15.799999999999999
#
# Iteration 48:
#   My bid            : 0.20
#   All bids          : [0.2        0.05732752 0.02616039 0.03933924 0.08150844 0.06045968
#  0.0545144  0.03627441 0.07713921 0.00479672 0.06329195]
#   Winners           : [0, 4, 8]
#   My win            : 1
#   m_t[48]          : 0.20
#   c_t               : 0.20
#   Total wins so far : 32
#   Current payment : 0.2
#   Total paid so far : 15.999999999999998
#
# Iteration 49:
#   My bid            : 0.00
#   All bids          : [0.         0.19331539 0.34431556 0.12678834 0.40684181 0.37108308
#  0.28957952 0.09989649 0.22455799 0.07459283 0.35181999]
#   Winners           : [4, 5, 10]
#   My win            : 0
#   m_t[49]          : 0.41
#   c_t               : 0.00
#   Total wins so far : 32
#   Current payment : 0.0
#   Total paid so far : 15.999999999999998
#
# Iteration 50:
#   My bid            : 0.00
#   All bids          : [0.         0.76172682 0.65697649 0.24637361 0.61734705 0.23807422
#  0.85848711 0.68905748 0.32525141 0.37242533 0.84194353]
#   Winners           : [6, 10, 1]
#   My win            : 0
#   m_t[50]          : 0.86
#   c_t               : 0.00
#   Total wins so far : 32
#   Current payment : 0.0
#   Total paid so far : 15.999999999999998
#
# Iteration 51:
#   My bid            : 0.40
#   All bids          : [0.4        0.24517622 0.29561808 0.14550843 0.48598255 0.2966756
#  0.59262091 0.18720457 0.41291292 0.61085049 0.54591127]
#   Winners           : [9, 6, 10]
#   My win            : 0
#   m_t[51]          : 0.61
#   c_t               : 0.00
#   Total wins so far : 32
#   Current payment : 0.0
#   Total paid so far : 15.999999999999998
#
# Iteration 52:
#   My bid            : 0.10
#   All bids          : [0.1        0.11445615 0.09393674 0.09822513 0.00136766 0.17365393
#  0.05453005 0.15471084 0.00255725 0.04100647 0.16759613]
#   Winners           : [5, 10, 7]
#   My win            : 0
#   m_t[52]          : 0.17
#   c_t               : 0.00
#   Total wins so far : 32
#   Current payment : 0.0
#   Total paid so far : 15.999999999999998
#
# Iteration 53:
#   My bid            : 0.10
#   All bids          : [0.1        0.00060162 0.00321125 0.01315064 0.01334012 0.00403089
#  0.009148   0.01094715 0.00100846 0.00587263 0.01875795]
#   Winners           : [0, 10, 4]
#   My win            : 1
#   m_t[53]          : 0.10
#   c_t               : 0.10
#   Total wins so far : 33
#   Current payment : 0.1
#   Total paid so far : 16.099999999999998
#
# Iteration 54:
#   My bid            : 0.30
#   All bids          : [0.3        0.00561895 0.01320154 0.01739303 0.03362973 0.02805355
#  0.03979595 0.00819801 0.02365982 0.00132505 0.04143838]
#   Winners           : [0, 10, 6]
#   My win            : 1
#   m_t[54]          : 0.30
#   c_t               : 0.30
#   Total wins so far : 34
#   Current payment : 0.30000000000000004
#   Total paid so far : 16.4
#
# Iteration 55:
#   My bid            : 0.00
#   All bids          : [0.         0.19925639 0.14634372 0.18801227 0.09636079 0.22009583
#  0.20683003 0.03041375 0.13725692 0.08694015 0.20183815]
#   Winners           : [5, 6, 10]
#   My win            : 0
#   m_t[55]          : 0.22
#   c_t               : 0.00
#   Total wins so far : 34
#   Current payment : 0.0
#   Total paid so far : 16.4
#
# Iteration 56:
#   My bid            : 0.30
#   All bids          : [0.3        0.54093174 0.49032235 0.59107503 0.2919881  0.62432769
#  0.19298186 0.06494218 0.21334562 0.68172113 0.28225195]
#   Winners           : [9, 5, 3]
#   My win            : 0
#   m_t[56]          : 0.68
#   c_t               : 0.00
#   Total wins so far : 34
#   Current payment : 0.0
#   Total paid so far : 16.4
#
# Iteration 57:
#   My bid            : 0.10
#   All bids          : [0.1        0.30425308 0.02908155 0.00332875 0.5840167  0.52080557
#  0.4523151  0.5448366  0.45795456 0.55076904 0.04299627]
#   Winners           : [4, 9, 7]
#   My win            : 0
#   m_t[57]          : 0.58
#   c_t               : 0.00
#   Total wins so far : 34
#   Current payment : 0.0
#   Total paid so far : 16.4
#
# Iteration 58:
#   My bid            : 0.30
#   All bids          : [0.3        0.13603946 0.30207942 0.18450338 0.04049718 0.27599606
#  0.24537905 0.02838442 0.13099124 0.01165501 0.10121725]
#   Winners           : [2, 0, 5]
#   My win            : 1
#   m_t[58]          : 0.30
#   c_t               : 0.30
#   Total wins so far : 35
#   Current payment : 0.3020794209934033
#   Total paid so far : 16.702079420993403
#
# Iteration 59:
#   My bid            : 0.40
#   All bids          : [0.4        0.0373624  0.05540925 0.04231056 0.01502067 0.05056515
#  0.00496905 0.00644279 0.03299673 0.0518766  0.01130295]
#   Winners           : [0, 2, 9]
#   My win            : 1
#   m_t[59]          : 0.40
#   c_t               : 0.40
#   Total wins so far : 36
#   Current payment : 0.4
#   Total paid so far : 17.1020794209934
#
# Iteration 60:
#   My bid            : 0.00
#   All bids          : [0.         0.00330011 0.00172497 0.00494868 0.00636298 0.00184606
#  0.01178749 0.01147488 0.00379077 0.00014684 0.01015777]
#   Winners           : [6, 7, 10]
#   My win            : 0
#   m_t[60]          : 0.01
#   c_t               : 0.00
#   Total wins so far : 36
#   Current payment : 0.0
#   Total paid so far : 17.1020794209934
#
# Iteration 61:
#   My bid            : 0.20
#   All bids          : [0.2        0.07936974 0.18783197 0.02816087 0.07197692 0.13344346
#  0.03134199 0.1458369  0.15198874 0.20623427 0.12198041]
#   Winners           : [9, 0, 2]
#   My win            : 1
#   m_t[61]          : 0.21
#   c_t               : 0.21
#   Total wins so far : 37
#   Current payment : 0.2062342741127843
#   Total paid so far : 17.308313695106186
#
# Iteration 62:
#   My bid            : 0.40
#   All bids          : [0.4        0.3340931  0.03792556 0.0926603  0.57475543 0.30559419
#  0.5845936  0.36178885 0.16858943 0.34185782 0.55881612]
#   Winners           : [6, 4, 10]
#   My win            : 0
#   m_t[62]          : 0.58
#   c_t               : 0.00
#   Total wins so far : 37
#   Current payment : 0.0
#   Total paid so far : 17.308313695106186
#
# Iteration 63:
#   My bid            : 0.20
#   All bids          : [0.2        0.2751613  0.10754077 0.71513007 0.352924   0.72339036
#  0.5464465  0.0702933  0.7419643  0.21636138 0.69715753]
#   Winners           : [8, 5, 3]
#   My win            : 0
#   m_t[63]          : 0.74
#   c_t               : 0.00
#   Total wins so far : 37
#   Current payment : 0.0
#   Total paid so far : 17.308313695106186
#
# Iteration 64:
#   My bid            : 0.00
#   All bids          : [0.         0.05422704 0.44731306 0.21189194 0.23350031 0.37705272
#  0.21592335 0.35848807 0.2259931  0.1232195  0.34943374]
#   Winners           : [2, 5, 7]
#   My win            : 0
#   m_t[64]          : 0.45
#   c_t               : 0.00
#   Total wins so far : 37
#   Current payment : 0.0
#   Total paid so far : 17.308313695106186
#
# Iteration 65:
#   My bid            : 0.30
#   All bids          : [0.3        0.09457043 0.06418525 0.07554273 0.10528108 0.04350253
#  0.0699037  0.05029229 0.0521654  0.0525989  0.03141639]
#   Winners           : [0, 4, 1]
#   My win            : 1
#   m_t[65]          : 0.30
#   c_t               : 0.30
#   Total wins so far : 38
#   Current payment : 0.30000000000000004
#   Total paid so far : 17.608313695106187
#
# Iteration 66:
#   My bid            : 0.40
#   All bids          : [4.00000000e-01 2.15844569e-05 1.89115052e-05 8.80995818e-05
#  2.79797662e-05 5.97471304e-05 3.64491903e-05 5.89596397e-05
#  6.11615348e-05 6.75593717e-05 7.78111720e-05]
#   Winners           : [0, 3, 10]
#   My win            : 1
#   m_t[66]          : 0.40
#   c_t               : 0.40
#   Total wins so far : 39
#   Current payment : 0.4
#   Total paid so far : 18.008313695106185
#
# Iteration 67:
#   My bid            : 0.30
#   All bids          : [0.3        0.11420879 0.07943263 0.08511415 0.11020853 0.02958893
#  0.0037992  0.10522858 0.06907917 0.091893   0.07743815]
#   Winners           : [0, 1, 4]
#   My win            : 1
#   m_t[67]          : 0.30
#   c_t               : 0.30
#   Total wins so far : 40
#   Current payment : 0.30000000000000004
#   Total paid so far : 18.308313695106186
#
# Iteration 68:
#   My bid            : 0.70
#   All bids          : [0.7        0.00113327 0.10034729 0.15499855 0.37527709 0.44253781
#  0.27530361 0.09091654 0.25156798 0.43866255 0.07854421]
#   Winners           : [0, 5, 9]
#   My win            : 1
#   m_t[68]          : 0.70
#   c_t               : 0.70
#   Total wins so far : 41
#   Current payment : 0.7000000000000001
#   Total paid so far : 19.008313695106185
#
# Iteration 69:
#   My bid            : 0.30
#   All bids          : [0.3        0.21853031 0.42091808 0.59143892 0.91610275 0.05365475
#  0.64970479 0.45586653 0.52534225 0.07376178 0.37468439]
#   Winners           : [4, 6, 3]
#   My win            : 0
#   m_t[69]          : 0.92
#   c_t               : 0.00
#   Total wins so far : 41
#   Current payment : 0.0
#   Total paid so far : 19.008313695106185
#
# Iteration 70:
#   My bid            : 0.60
#   All bids          : [0.6        0.49098471 0.37486484 0.06816202 0.47149905 0.29153768
#  0.28487516 0.19629981 0.21345788 0.42016537 0.10883892]
#   Winners           : [0, 1, 4]
#   My win            : 1
#   m_t[70]          : 0.60
#   c_t               : 0.60
#   Total wins so far : 42
#   Current payment : 0.6000000000000001
#   Total paid so far : 19.608313695106187
#
# Iteration 71:
#   My bid            : 0.00
#   All bids          : [0.         0.027155   0.18194279 0.15123605 0.07859157 0.00803064
#  0.13591055 0.13442237 0.1173152  0.02908252 0.11945178]
#   Winners           : [2, 3, 6]
#   My win            : 0
#   m_t[71]          : 0.18
#   c_t               : 0.00
#   Total wins so far : 42
#   Current payment : 0.0
#   Total paid so far : 19.608313695106187
#
# Iteration 72:
#   My bid            : 0.00
#   All bids          : [0.         0.00712513 0.00048314 0.00060661 0.00639177 0.003216
#  0.000152   0.00737394 0.00580814 0.00019251 0.00523177]
#   Winners           : [7, 1, 4]
#   My win            : 0
#   m_t[72]          : 0.01
#   c_t               : 0.00
#   Total wins so far : 42
#   Current payment : 0.0
#   Total paid so far : 19.608313695106187
#
# Iteration 73:
#   My bid            : 0.50
#   All bids          : [5.00000000e-01 3.55879535e-04 2.05912832e-02 1.26931333e-02
#  1.93893168e-02 8.35343503e-03 3.53428362e-02 3.20919063e-02
#  4.94511504e-02 4.20672335e-02 2.04291135e-02]
#   Winners           : [0, 8, 9]
#   My win            : 1
#   m_t[73]          : 0.50
#   c_t               : 0.50
#   Total wins so far : 43
#   Current payment : 0.5
#   Total paid so far : 20.108313695106187
#
# Iteration 74:
#   My bid            : 0.20
#   All bids          : [0.2        0.12440514 0.25550039 0.09817295 0.05200967 0.11912524
#  0.11767057 0.06951338 0.16780314 0.11038816 0.26716299]
#   Winners           : [10, 2, 0]
#   My win            : 1
#   m_t[74]          : 0.27
#   c_t               : 0.27
#   Total wins so far : 44
#   Current payment : 0.2671629930164386
#   Total paid so far : 20.375476688122625
#
# Iteration 75:
#   My bid            : 0.10
#   All bids          : [0.1        0.67636711 0.25771766 0.09733084 0.3910392  0.62397362
#  0.6153407  0.22084579 0.63208087 0.30589454 0.58108218]
#   Winners           : [1, 8, 5]
#   My win            : 0
#   m_t[75]          : 0.68
#   c_t               : 0.00
#   Total wins so far : 44
#   Current payment : 0.0
#   Total paid so far : 20.375476688122625
#
# Iteration 76:
#   My bid            : 0.60
#   All bids          : [0.6        0.53216066 0.08555343 0.49329735 0.14135973 0.18869497
#  0.14023088 0.49880149 0.56588368 0.63508736 0.67136386]
#   Winners           : [10, 9, 0]
#   My win            : 1
#   m_t[76]          : 0.67
#   c_t               : 0.67
#   Total wins so far : 45
#   Current payment : 0.6713638596704526
#   Total paid so far : 21.046840547793078
#
# Iteration 77:
#   My bid            : 0.20
#   All bids          : [0.2        0.21599823 0.13331453 0.10900858 0.27941846 0.22980056
#  0.17437503 0.14225381 0.17752449 0.11698338 0.0525094 ]
#   Winners           : [4, 5, 1]
#   My win            : 0
#   m_t[77]          : 0.28
#   c_t               : 0.00
#   Total wins so far : 45
#   Current payment : 0.0
#   Total paid so far : 21.046840547793078
#
# Iteration 78:
#   My bid            : 0.40
#   All bids          : [0.4        0.01632508 0.02972003 0.00537952 0.01265767 0.0174214
#  0.01882325 0.02437894 0.01988276 0.01151227 0.00465024]
#   Winners           : [0, 2, 7]
#   My win            : 1
#   m_t[78]          : 0.40
#   c_t               : 0.40
#   Total wins so far : 46
#   Current payment : 0.4
#   Total paid so far : 21.446840547793077
#
# Iteration 79:
#   My bid            : 0.40
#   All bids          : [0.4        0.00604641 0.01094968 0.00802962 0.00989052 0.02183951
#  0.01168438 0.00199905 0.01936578 0.00620735 0.00188565]
#   Winners           : [0, 5, 8]
#   My win            : 1
#   m_t[79]          : 0.40
#   c_t               : 0.40
#   Total wins so far : 47
#   Current payment : 0.4
#   Total paid so far : 21.846840547793075
#
# Iteration 80:
#   My bid            : 0.60
#   All bids          : [6.00000000e-01 4.72501193e-02 1.43246241e-01 3.32875618e-02
#  2.14394966e-01 7.52483271e-02 6.06164462e-02 1.40592223e-01
#  4.34894316e-02 4.56109390e-04 2.23000594e-01]
#   Winners           : [0, 10, 4]
#   My win            : 1
#   m_t[80]          : 0.60
#   c_t               : 0.60
#   Total wins so far : 48
#   Current payment : 0.6000000000000001
#   Total paid so far : 22.446840547793077
#
# Iteration 81:
#   My bid            : 0.30
#   All bids          : [0.3        0.38622242 0.32993143 0.60835698 0.52625578 0.36975856
#  0.25350424 0.2511926  0.44270573 0.22486938 0.58085128]
#   Winners           : [3, 10, 4]
#   My win            : 0
#   m_t[81]          : 0.61
#   c_t               : 0.00
#   Total wins so far : 48
#   Current payment : 0.0
#   Total paid so far : 22.446840547793077
#
# Iteration 82:
#   My bid            : 0.40
#   All bids          : [0.4        0.21769191 0.2291189  0.35788149 0.7335414  0.71369143
#  0.23220279 0.18594349 0.36353777 0.3683103  0.67414192]
#   Winners           : [4, 5, 10]
#   My win            : 0
#   m_t[82]          : 0.73
#   c_t               : 0.00
#   Total wins so far : 48
#   Current payment : 0.0
#   Total paid so far : 22.446840547793077
#
# Iteration 83:
#   My bid            : 0.20
#   All bids          : [0.2        0.36355276 0.24006423 0.30926436 0.2900186  0.38120739
#  0.170435   0.23819445 0.32157949 0.30832133 0.06754498]
#   Winners           : [5, 1, 8]
#   My win            : 0
#   m_t[83]          : 0.38
#   c_t               : 0.00
#   Total wins so far : 48
#   Current payment : 0.0
#   Total paid so far : 22.446840547793077
#
# Iteration 84:
#   My bid            : 0.10
#   All bids          : [0.1        0.06341971 0.0824664  0.03840654 0.04317498 0.07424709
#  0.02926665 0.07358147 0.03068569 0.07843761 0.05268046]
#   Winners           : [0, 2, 9]
#   My win            : 1
#   m_t[84]          : 0.10
#   c_t               : 0.10
#   Total wins so far : 49
#   Current payment : 0.1
#   Total paid so far : 22.546840547793078
#
# Iteration 85:
#   My bid            : 0.60
#   All bids          : [6.00000000e-01 3.08109802e-03 2.67924405e-03 2.02243277e-03
#  8.75321159e-05 3.74575330e-03 2.78439036e-03 1.71940224e-03
#  2.56315222e-03 9.18371574e-04 3.50592477e-04]
#   Winners           : [0, 5, 1]
#   My win            : 1
#   m_t[85]          : 0.60
#   c_t               : 0.60
#   Total wins so far : 50
#   Current payment : 0.6000000000000001
#   Total paid so far : 23.14684054779308
#
# Iteration 86:
#   My bid            : 0.20
#   All bids          : [0.2        0.13007053 0.04819627 0.10170218 0.07167943 0.14999444
#  0.0497062  0.07946008 0.05844274 0.04406148 0.04927354]
#   Winners           : [0, 5, 1]
#   My win            : 1
#   m_t[86]          : 0.20
#   c_t               : 0.20
#   Total wins so far : 51
#   Current payment : 0.2
#   Total paid so far : 23.34684054779308
#
# Iteration 87:
#   My bid            : 0.70
#   All bids          : [0.7        0.08627122 0.18551851 0.23196377 0.01828938 0.17475333
#  0.25143811 0.01180348 0.22410265 0.48758872 0.08404268]
#   Winners           : [0, 9, 6]
#   My win            : 1
#   m_t[87]          : 0.70
#   c_t               : 0.70
#   Total wins so far : 52
#   Current payment : 0.7000000000000001
#   Total paid so far : 24.046840547793078
#
# Iteration 88:
#   My bid            : 0.40
#   All bids          : [0.4        0.74621749 0.31066283 0.84542814 0.25008942 0.41331988
#  0.02390033 0.1493933  0.56225364 0.7886749  0.67475201]
#   Winners           : [3, 9, 1]
#   My win            : 0
#   m_t[88]          : 0.85
#   c_t               : 0.00
#   Total wins so far : 52
#   Current payment : 0.0
#   Total paid so far : 24.046840547793078
#
# Iteration 89:
#   My bid            : 0.30
#   All bids          : [0.3        0.45469365 0.03293248 0.34461723 0.23057312 0.35887518
#  0.31202042 0.05686576 0.12992217 0.45134345 0.35366872]
#   Winners           : [1, 9, 5]
#   My win            : 0
#   m_t[89]          : 0.45
#   c_t               : 0.00
#   Total wins so far : 52
#   Current payment : 0.0
#   Total paid so far : 24.046840547793078
#
# Iteration 90:
#   My bid            : 0.00
#   All bids          : [0.         0.08166232 0.0746289  0.00813353 0.00198732 0.04711797
#  0.03546084 0.035874   0.11612019 0.09207307 0.06007424]
#   Winners           : [8, 9, 1]
#   My win            : 0
#   m_t[90]          : 0.12
#   c_t               : 0.00
#   Total wins so far : 52
#   Current payment : 0.0
#   Total paid so far : 24.046840547793078
#
# Iteration 91:
#   My bid            : 0.70
#   All bids          : [7.00000000e-01 8.43161432e-04 1.15938439e-04 7.01202464e-04
#  6.67585387e-05 8.41419526e-04 2.17542736e-04 2.81306615e-04
#  1.09168540e-03 1.37999721e-03 7.26510345e-04]
#   Winners           : [0, 9, 8]
#   My win            : 1
#   m_t[91]          : 0.70
#   c_t               : 0.70
#   Total wins so far : 53
#   Current payment : 0.7000000000000001
#   Total paid so far : 24.746840547793077
#
# Iteration 92:
#   My bid            : 0.20
#   All bids          : [0.2        0.07370514 0.054547   0.07563635 0.08061825 0.0858782
#  0.03044119 0.06734828 0.0139346  0.02172634 0.04127543]
#   Winners           : [0, 5, 4]
#   My win            : 1
#   m_t[92]          : 0.20
#   c_t               : 0.20
#   Total wins so far : 54
#   Current payment : 0.2
#   Total paid so far : 24.946840547793077
#
# Iteration 93:
#   My bid            : 0.30
#   All bids          : [0.3        0.20652467 0.28873456 0.17170425 0.02595995 0.16454076
#  0.02893591 0.02120212 0.11104759 0.02216533 0.34324661]
#   Winners           : [10, 0, 2]
#   My win            : 1
#   m_t[93]          : 0.34
#   c_t               : 0.34
#   Total wins so far : 55
#   Current payment : 0.34324660837239146
#   Total paid so far : 25.29008715616547
#
# Iteration 94:
#   My bid            : 0.20
#   All bids          : [0.2        0.03681195 0.65077085 0.57683113 0.419036   0.54619089
#  0.37233167 0.87066495 0.20984324 0.66594106 0.74061069]
#   Winners           : [7, 10, 9]
#   My win            : 0
#   m_t[94]          : 0.87
#   c_t               : 0.00
#   Total wins so far : 55
#   Current payment : 0.0
#   Total paid so far : 25.29008715616547
#
# Iteration 95:
#   My bid            : 0.10
#   All bids          : [0.1        0.32431258 0.53902568 0.26986592 0.63047745 0.63185563
#  0.1971923  0.23385649 0.20899612 0.58511408 0.19356365]
#   Winners           : [5, 4, 9]
#   My win            : 0
#   m_t[95]          : 0.63
#   c_t               : 0.00
#   Total wins so far : 55
#   Current payment : 0.0
#   Total paid so far : 25.29008715616547
#
# Iteration 96:
#   My bid            : 0.60
#   All bids          : [0.6        0.10033057 0.12978342 0.09755924 0.11007424 0.03039364
#  0.15368936 0.00385841 0.12412658 0.00387051 0.0494656 ]
#   Winners           : [0, 6, 2]
#   My win            : 1
#   m_t[96]          : 0.60
#   c_t               : 0.60
#   Total wins so far : 56
#   Current payment : 0.6000000000000001
#   Total paid so far : 25.89008715616547
#
# Iteration 97:
#   My bid            : 0.30
#   All bids          : [0.3        0.0010713  0.00367943 0.01322807 0.01629584 0.00726922
#  0.00461722 0.01209867 0.01344472 0.01395746 0.01011731]
#   Winners           : [0, 4, 9]
#   My win            : 1
#   m_t[97]          : 0.30
#   c_t               : 0.30
#   Total wins so far : 57
#   Current payment : 0.30000000000000004
#   Total paid so far : 26.190087156165472
#
# Iteration 98:
#   My bid            : 0.00
#   All bids          : [0.         0.01963501 0.03071301 0.01344795 0.02662274 0.00631192
#  0.00854533 0.0415066  0.03325987 0.0380884  0.02527155]
#   Winners           : [7, 9, 8]
#   My win            : 0
#   m_t[98]          : 0.04
#   c_t               : 0.00
#   Total wins so far : 57
#   Current payment : 0.0
#   Total paid so far : 26.190087156165472
#
# Iteration 99:
#   My bid            : 0.30
#   All bids          : [0.3        0.26027479 0.0627382  0.18800594 0.10356832 0.15584719
#  0.00042682 0.02359404 0.10504023 0.22745367 0.11852183]
#   Winners           : [0, 1, 9]
#   My win            : 1
#   m_t[99]          : 0.30
#   c_t               : 0.30
#   Total wins so far : 58
#   Current payment : 0.30000000000000004
#   Total paid so far : 26.490087156165472
# Total number of wins: 58

# %% [markdown]
# graphical representation

# %%
plt.plot(my_bids)
plt.xlabel('$t$')
plt.ylabel('$b_t$')
plt.title('Chosen Bids')
plt.show()

# %%
cumulative_payments = np.cumsum(my_payments)
plt.plot(cumulative_payments)
plt.xlabel('$t$')
plt.ylabel('$\sum c_t$')
plt.axhline(BUGDET, color='red', label='Budget')
plt.legend()
plt.title('Cumulative Payments of Multiplicative Pacing')
plt.show()

# %%
cumulative_regret = np.cumsum(expected_clairvoyant_utilities-utilities)
plt.plot(cumulative_regret)
plt.xlabel('$t$')
plt.ylabel('$\sum R_t$')
plt.title('Cumulative Regret of Multiplicative Pacing')
plt.show()


### PROBLEM: negative regret

# %% [markdown]
# # rework the clairvoyant to better the regret (or try something)

# %% [markdown]
# ## now doing multiple rounds to have a better idea

# %%
all_regrets = []
all_payments = []
for i in range(ITERATIONS):
    agent = FFMultiplicativePacingAgent(bids_set = available_bids,
                                        valuation=my_valuation,
                                        budget=BUGDET,
                                        T=N_USERS,
                                        eta=eta)

    auction = FirstPriceAuction(np.ones(N_ADVERTISERS+1))
    utilities = np.array([])
    my_bids = np.array([])
    my_payments = np.array([])

    np.random.seed(i)
    for u in range(N_USERS):
        # Agent places a bid
        my_bid = agent.bid()

        # Gather all bids for this auction
        bids = np.append(my_bid, other_bids[:, u].ravel())
        m_t_new = np.max(bids)

        # Determine winners and payments
        winners, payments_per_click = auction.round(bids=bids)

        # Check if the agent won
        my_win = int(winners == 0)  # Agent wins if winners is 0

        # Calculate the utility and payment for the agent
        f_t = (my_valuation - m_t_new) * my_win  # Utility when the agent wins
        c_t = m_t_new * my_win  # Payment if the agent wins

        # Update the agent's learning based on the auction outcome
        agent.update(f_t, c_t, m_t_new)

        # Store the results
        utilities = np.append(utilities, f_t)  # Append utility
        my_bids = np.append(my_bids, my_bid)  # Append bid
        my_payments = np.append(my_payments, c_t)  # Append payment
        total_wins += my_win  # Increment total wins

        cumulative_payments = np.cumsum(my_payments)


    all_regrets.append(np.cumsum(expected_clairvoyant_utilities-utilities))
    all_payments.append(cumulative_payments)

avg_regret = np.array(all_regrets).mean(axis=0)
std_regret = np.array(all_regrets).std(axis=0)

avg_payments = np.array(all_payments).mean(axis=0)
std_payments = np.array(all_payments).std(axis=0)

# %%
### SAME OF BEFORE, THIS IS THE NEW BLOCK FOR MULTIPLE SLOTS
all_regrets = []
all_payments = []
for i in range(ITERATIONS):
    agent = FFMultiplicativePacingAgent(bids_set = available_bids,
                                        valuation=my_valuation,
                                        budget=BUGDET,
                                        T=N_USERS,
                                        eta=eta)

    auction = FirstPriceAuction(np.ones(N_ADVERTISERS+1))
    utilities = np.array([])
    my_bids = np.array([])
    my_payments = np.array([])

    np.random.seed(i)
    for u in range(N_USERS):
        my_win = 0
        rank = 0
        # Agent places a bid
        my_bid = agent.bid()

        # Gather all bids for this auction
        bids = np.append(my_bid, other_bids[:, u].ravel())
        m_t_new = np.max(bids)

        # Determine winners and payments
        winners, payments_per_click = auction.get_winners(bids=bids)
        x = len(winners)

        # Check if the agent won
        for i in range(x):
          if winners[i]==0:
            my_win = 1
            rank = i

        # Calculate the utility and payment for the agent
        f_t = (my_valuation[rank] - m_t_new) * my_win  # Utility when the agent wins
        c_t = m_t_new * my_win  # Payment if the agent wins

        # Update the agent's learning based on the auction outcome
        agent.update(f_t, c_t, m_t_new)

        # Store the results
        utilities = np.append(utilities, f_t)  # Append utility
        my_bids = np.append(my_bids, my_bid)  # Append bid
        my_payments = np.append(my_payments, c_t)  # Append payment
        total_wins += my_win  # Increment total wins

        cumulative_payments = np.cumsum(my_payments)


    all_regrets.append(np.cumsum(expected_clairvoyant_utilities-utilities))
    all_payments.append(cumulative_payments)

avg_regret = np.array(all_regrets).mean(axis=0)
std_regret = np.array(all_regrets).std(axis=0)

avg_payments = np.array(all_payments).mean(axis=0)
std_payments = np.array(all_payments).std(axis=0)

# %% [markdown]
# graphical representation

# %%
plt.plot(np.arange(N_USERS), avg_payments)
plt.fill_between(np.arange(N_USERS), avg_payments-std_payments, avg_payments+std_payments, alpha=0.3)
plt.xlabel('$t$')
plt.ylabel('$\sum c_t$')
plt.axhline(BUGDET, color='red', label='Budget')
plt.legend()
plt.title('Cumulative Payments of Multiplicative Pacing')
plt.show()

# %%
plt.plot(np.arange(N_USERS), avg_regret)
plt.fill_between(np.arange(N_USERS), avg_regret-std_regret, avg_regret+std_regret, alpha=0.3)
plt.xlabel('$t$')
plt.ylabel('$\sum R_t$')
plt.title('Cumulative Regret of Full-Feedback Multiplicative Pacing')
plt.show()
